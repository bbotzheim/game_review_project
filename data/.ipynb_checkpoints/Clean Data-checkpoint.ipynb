# %%
import pandas as pd
import numpy as np
import matplotlib as plt


games = pd.read_csv('games.csv')
game_reviews = pd.read_csv('game_reviews.csv')

# %% [markdown]
# Data cleaning jobs:
# - other tables and inserting IDs instead of taking up space with strings?
#     - users, developers, platform, genres, publishers
# - Do tags need to exist in the review table to carry over to the recommendation system?
#     - thus does the review table need the genre tags, game title, platform, etc. in order to filter options?
#     - or can they be brought in from the other tables?
# - null values: blank fields from an issue picking up the data? or from no data to pick up?
# - date column as date data type

# %% [markdown]
# ## Games Table

# %% [markdown]
# #### Generate Game ID on game table and join on review table:

# %%
# add game_id column
ids = pd.Series(range(10000, 26961))
games = pd.concat((ids, games), axis=1)
games.head()
# Out:
#        0 ESRB_rating  average_user_score        developer  \
# 0  10000           T                 7.6  Criterion Games
# 1  10001           T                 8.7      Flight-Plan
# 2  10002           E                 4.6     Proper Games
# 3  10003         NaN                 6.8  Pendulo Studios
# 4  10004         NaN                 7.6     damiansommer
#
#                                               genres  metascore  \
# 0                            Driving, Racing, Arcade       94.0
# 1                                  Strategy, General       65.0
# 2  Miscellaneous, Puzzle, Action, Puzzle, General...       65.0
# 3       Adventure, General, General, Point-and-Click       65.0
# 4                        Adventure, General, General       66.0
#
#         platform               publisher  release_date  \
# 0           Xbox                EA Games  Sep  7, 2004
# 1  PlayStation 2               Atlus Co.  Nov 11, 2008
# 2             PC                  Capcom  Apr  7, 2009
# 3             PC  Focus Home Interactive  Mar 22, 2012
# 4             PC            damiansommer  Jun 14, 2013
#
#                                              summary                title  \
# 0  Burnout 3 challenges you to crash into (and th...  Burnout 3: Takedown
# 1  Our world descended into chaos the day the dem...       Eternal Poison
# 2  FLOCK! uses a sophisticated physics engine tha...               Flock!
# 3  (Also known as "New York Crimes") In New York ...            Yesterday
# 4  The evil Yawhg is returning. How will the town...            The Yawhg
#
#                                                  url
# 0  https://www.metacritic.com/game/xbox/burnout-3...
# 1  https://www.metacritic.com/game/playstation-2/...
# 2          https://www.metacritic.com/game/pc/flock!
# 3       https://www.metacritic.com/game/pc/yesterday
# 4       https://www.metacritic.com/game/pc/the-yawhg

# %%
# re-name game_ID column and re-arrange columns for easier reading
games.columns = ['game_ID',        'ESRB_rating', 'average_user_score',
                'developer',             'genres',          'metascore',
                 'platform',          'publisher',       'release_date',
                  'summary',              'title',                'url']
games = games[['game_ID', 'title', 'platform', 'metascore', 'average_user_score', 'summary', 'genres',
'developer',  'publisher', 'release_date','ESRB_rating', 'url']]
games.head()
# Out:
#    game_ID                title       platform  metascore  average_user_score  \
# 0    10000  Burnout 3: Takedown           Xbox       94.0                 7.6
# 1    10001       Eternal Poison  PlayStation 2       65.0                 8.7
# 2    10002               Flock!             PC       65.0                 4.6
# 3    10003            Yesterday             PC       65.0                 6.8
# 4    10004            The Yawhg             PC       66.0                 7.6
#
#                                              summary  \
# 0  Burnout 3 challenges you to crash into (and th...
# 1  Our world descended into chaos the day the dem...
# 2  FLOCK! uses a sophisticated physics engine tha...
# 3  (Also known as "New York Crimes") In New York ...
# 4  The evil Yawhg is returning. How will the town...
#
#                                               genres        developer  \
# 0                            Driving, Racing, Arcade  Criterion Games
# 1                                  Strategy, General      Flight-Plan
# 2  Miscellaneous, Puzzle, Action, Puzzle, General...     Proper Games
# 3       Adventure, General, General, Point-and-Click  Pendulo Studios
# 4                        Adventure, General, General     damiansommer
#
#                 publisher  release_date ESRB_rating  \
# 0                EA Games  Sep  7, 2004           T
# 1               Atlus Co.  Nov 11, 2008           T
# 2                  Capcom  Apr  7, 2009           E
# 3  Focus Home Interactive  Mar 22, 2012         NaN
# 4            damiansommer  Jun 14, 2013         NaN
#
#                                                  url
# 0  https://www.metacritic.com/game/xbox/burnout-3...
# 1  https://www.metacritic.com/game/playstation-2/...
# 2          https://www.metacritic.com/game/pc/flock!
# 3       https://www.metacritic.com/game/pc/yesterday
# 4       https://www.metacritic.com/game/pc/the-yawhg

# %% [markdown]
# #### Missingness?

# %%
games.isnull().sum()
# Not all games had enough reviews for scores (much more common for user scores)
# Not all games had summaries
# Not all games had ratings
# Out:
# game_ID                  0
# title                    0
# platform                 0
# metascore                7
# average_user_score    1219
# summary                152
# genres                   0
# developer                0
# publisher                0
# release_date             0
# ESRB_rating           1548
# url                      0
# dtype: int64

# %% [markdown]
# #### Creating Genres table, Creating table to identify genre tags for each game

# %%
# grabbing all genres from games table
genres = []
for row in games.genres:
    genre_list = row.split(sep = ', ')
    for item in genre_list:
        if item not in genres:
            genres.append(item)


# creating genre table
genres = pd.DataFrame(genres)
ids = pd.Series(range(1, 170))
genres = pd.concat((genres, ids), axis=1)
genres.columns = ['genre_name', 'genre_ID']
genres.head()
# Out:
#   genre_name  genre_ID
# 0    Driving         1
# 1     Racing         2
# 2     Arcade         3
# 3   Strategy         4
# 4    General         5

# %%
# Creating table to identify genre tags for each game (for easy querying)
game_genre_tags = pd.DataFrame(columns = ['game_ID', 'genre_name'])

for index, row in games.iterrows():
    genre_list = row[6].split(sep = ', ')
    for item in genre_list:
        df = pd.DataFrame([[row[0], item]], columns = ['game_ID', 'genre_name'])
        game_genre_tags = game_genre_tags.append(df)
game_genre_tags.head()
# Out:
#   game_ID genre_name
# 0   10000    Driving
# 0   10000     Racing
# 0   10000     Arcade
# 0   10001   Strategy
# 0   10001    General

# %%
#Join genres and game genre tags
game_genre_tags = pd.merge(game_genre_tags, genres, how = "left", on = ['genre_name'])

#Drop genre_name column
game_genre_tags = game_genre_tags.drop(['genre_name'], 1)
game_genre_tags.head()
# Out:
#   game_ID  genre_ID
# 0   10000         1
# 1   10000         2
# 2   10000         3
# 3   10001         4
# 4   10001         5

# %%
#### Update Game Table
# Drop unnecessary columns from game table
games = games.drop(['genres'], 1)
games.head()
# Out:
#    game_ID                title       platform  metascore  average_user_score  \
# 0    10000  Burnout 3: Takedown           Xbox       94.0                 7.6
# 1    10001       Eternal Poison  PlayStation 2       65.0                 8.7
# 2    10002               Flock!             PC       65.0                 4.6
# 3    10003            Yesterday             PC       65.0                 6.8
# 4    10004            The Yawhg             PC       66.0                 7.6
#
#                                              summary        developer  \
# 0  Burnout 3 challenges you to crash into (and th...  Criterion Games
# 1  Our world descended into chaos the day the dem...      Flight-Plan
# 2  FLOCK! uses a sophisticated physics engine tha...     Proper Games
# 3  (Also known as "New York Crimes") In New York ...  Pendulo Studios
# 4  The evil Yawhg is returning. How will the town...     damiansommer
#
#                 publisher  release_date ESRB_rating  \
# 0                EA Games  Sep  7, 2004           T
# 1               Atlus Co.  Nov 11, 2008           T
# 2                  Capcom  Apr  7, 2009           E
# 3  Focus Home Interactive  Mar 22, 2012         NaN
# 4            damiansommer  Jun 14, 2013         NaN
#
#                                                  url
# 0  https://www.metacritic.com/game/xbox/burnout-3...
# 1  https://www.metacritic.com/game/playstation-2/...
# 2          https://www.metacritic.com/game/pc/flock!
# 3       https://www.metacritic.com/game/pc/yesterday
# 4       https://www.metacritic.com/game/pc/the-yawhg

# %% [markdown]
# #### Misc tables?

# %%
#### Create Platform Table
platforms = pd.DataFrame(games.platform.drop_duplicates())
platforms = platforms.reset_index(drop=True)
ids = pd.Series(range(1, 21))
platforms = pd.concat((platforms, ids), axis=1)
platforms.columns = ['platform', 'platform_ID']
platforms.head()
# Out:
#         platform  platform_ID
# 0           Xbox            1
# 1  PlayStation 2            2
# 2             PC            3
# 3  PlayStation 4            4
# 4  PlayStation 3            5

# %%
#### Create Developer table
developers = pd.DataFrame(games.developer.drop_duplicates())
developers = developers.reset_index(drop=True)
ids = pd.Series(range(1, 4080))
developers = pd.concat((developers, ids), axis=1)
developers.columns = ['developer', 'developer_ID']
developers.head()
# Out:
#          developer  developer_ID
# 0  Criterion Games             1
# 1      Flight-Plan             2
# 2     Proper Games             3
# 3  Pendulo Studios             4
# 4     damiansommer             5

# %%
#### Create Publisher table
publishers = pd.DataFrame(games.publisher.drop_duplicates())
publishers = publishers.reset_index(drop=True)
ids = pd.Series(range(1, 1752))
publishers = pd.concat((publishers, ids), axis=1)
publishers.columns = ['publisher', 'publisher_ID']
publishers.head()
# Out:
#                 publisher  publisher_ID
# 0                EA Games             1
# 1               Atlus Co.             2
# 2                  Capcom             3
# 3  Focus Home Interactive             4
# 4            damiansommer             5

# %%
games.shape
# Out:
# (16961, 11)

# %%
# Update Game table
games = pd.merge(games, platforms, how = "left", on = ['platform'])
games = pd.merge(games, developers, how = "left", on = ['developer'])
games = pd.merge(games, publishers, how = "left", on = ['publisher'])
games = games.drop(['developer', 'platform', 'publisher'], 1)
games.head()
# Out:
#    game_ID                title       platform  metascore  average_user_score  \
# 0    10000  Burnout 3: Takedown           Xbox       94.0                 7.6
# 1    10001       Eternal Poison  PlayStation 2       65.0                 8.7
# 2    10002               Flock!             PC       65.0                 4.6
# 3    10003            Yesterday             PC       65.0                 6.8
# 4    10004            The Yawhg             PC       66.0                 7.6
#
#                                              summary  release_date  \
# 0  Burnout 3 challenges you to crash into (and th...  Sep  7, 2004
# 1  Our world descended into chaos the day the dem...  Nov 11, 2008
# 2  FLOCK! uses a sophisticated physics engine tha...  Apr  7, 2009
# 3  (Also known as "New York Crimes") In New York ...  Mar 22, 2012
# 4  The evil Yawhg is returning. How will the town...  Jun 14, 2013
#
#   ESRB_rating                                                url  platform_ID  \
# 0           T  https://www.metacritic.com/game/xbox/burnout-3...            1
# 1           T  https://www.metacritic.com/game/playstation-2/...            2
# 2           E          https://www.metacritic.com/game/pc/flock!            3
# 3         NaN       https://www.metacritic.com/game/pc/yesterday            3
# 4         NaN       https://www.metacritic.com/game/pc/the-yawhg            3
#
#    developer_ID  publisher_ID
# 0             1             1
# 1             2             2
# 2             3             3
# 3             4             4
# 4             5             5

# %%
games = games[['game_ID', 'title', 'platform_ID', 'metascore', 'average_user_score', 'summary',
'developer_ID',  'publisher_ID', 'release_date','ESRB_rating', 'url']]
games.head()
# Out:
#    game_ID                title  platform_ID  metascore  average_user_score  \
# 0    10000  Burnout 3: Takedown            1       94.0                 7.6
# 1    10001       Eternal Poison            2       65.0                 8.7
# 2    10002               Flock!            3       65.0                 4.6
# 3    10003            Yesterday            3       65.0                 6.8
# 4    10004            The Yawhg            3       66.0                 7.6
#
#                                              summary  developer_ID  \
# 0  Burnout 3 challenges you to crash into (and th...             1
# 1  Our world descended into chaos the day the dem...             2
# 2  FLOCK! uses a sophisticated physics engine tha...             3
# 3  (Also known as "New York Crimes") In New York ...             4
# 4  The evil Yawhg is returning. How will the town...             5
#
#    publisher_ID  release_date ESRB_rating  \
# 0             1  Sep  7, 2004           T
# 1             2  Nov 11, 2008           T
# 2             3  Apr  7, 2009           E
# 3             4  Mar 22, 2012         NaN
# 4             5  Jun 14, 2013         NaN
#
#                                                  url       platform
# 0  https://www.metacritic.com/game/xbox/burnout-3...           Xbox
# 1  https://www.metacritic.com/game/playstation-2/...  PlayStation 2
# 2          https://www.metacritic.com/game/pc/flock!             PC
# 3       https://www.metacritic.com/game/pc/yesterday             PC
# 4       https://www.metacritic.com/game/pc/the-yawhg             PC

# %%
games.shape
# Out:
# (16961, 12)

# %% [markdown]
# ## Reviews Table

# %%
game_reviews.shape
# Out:
# (1080624, 8)

# %% [markdown]
# #### Add Platform_ID Column

# %%
game_reviews = pd.merge(platforms, game_reviews, how = "right", on = ['platform'])
game_reviews = game_reviews.drop(['platform'], 1)
game_reviews.head()
# Out:
#    platform_ID  critic_flag date  \
# 0            1            1  NaN
# 1            1            1  NaN
# 2            1            1  NaN
# 3            1            1  NaN
# 4            1            1  NaN
#
#                                          review_text  score  \
# 0  To say that this game is "fast" is an understa...  100.0
# 1  Easy controls help you play chicken with oncom...  100.0
# 2  With its killer combo of great gameplay, aweso...  100.0
# 3  Every lap is terrifying...Polished to perfecti...  100.0
# 4  The combo of racing and combat is brilliantly ...  100.0
#
#                  title                                                url  \
# 0  Burnout 3: Takedown  https://www.metacritic.com/game/xbox/burnout-3...
# 1  Burnout 3: Takedown  https://www.metacritic.com/game/xbox/burnout-3...
# 2  Burnout 3: Takedown  https://www.metacritic.com/game/xbox/burnout-3...
# 3  Burnout 3: Takedown  https://www.metacritic.com/game/xbox/burnout-3...
# 4  Burnout 3: Takedown  https://www.metacritic.com/game/xbox/burnout-3...
#
#                     username
# 0                    GamePro
# 1               Maxim Online
# 2                      G4 TV
# 3  The Sydney Morning Herald
# 4       Entertainment Weekly

# %%
game_reviews.shape
# Out:
# (1080624, 8)

# %% [markdown]
# #### Add Game ID column from Games table:

# %%
### Join to get game_ID on game_reviews using the title + platform
game_ids = games[['game_ID', 'title', 'platform_ID']]
#game_reviews = 
pd.merge(game_ids, game_reviews, how = "inner", on = ['title', 'platform_ID'])

#drop extra columns
#game_reviews = game_reviews.drop(['title', 'platform_ID', 'url'], 1)
#game_reviews.head()
# Out:
#          game_ID                title  platform_ID  critic_flag          date  \
# 0          10000  Burnout 3: Takedown            1            1           NaN
# 1          10000  Burnout 3: Takedown            1            1           NaN
# 2          10000  Burnout 3: Takedown            1            1           NaN
# 3          10000  Burnout 3: Takedown            1            1           NaN
# 4          10000  Burnout 3: Takedown            1            1           NaN
# 5          10000  Burnout 3: Takedown            1            1           NaN
# 6          10000  Burnout 3: Takedown            1            1           NaN
# 7          10000  Burnout 3: Takedown            1            1           NaN
# 8          10000  Burnout 3: Takedown            1            1           NaN
# 9          10000  Burnout 3: Takedown            1            1           NaN
# 10         10000  Burnout 3: Takedown            1            1           NaN
# 11         10000  Burnout 3: Takedown            1            1           NaN
# 12         10000  Burnout 3: Takedown            1            1           NaN
# 13         10000  Burnout 3: Takedown            1            1           NaN
# 14         10000  Burnout 3: Takedown            1            1           NaN
# 15         10000  Burnout 3: Takedown            1            1           NaN
# 16         10000  Burnout 3: Takedown            1            1           NaN
# 17         10000  Burnout 3: Takedown            1            1           NaN
# 18         10000  Burnout 3: Takedown            1            1           NaN
# 19         10000  Burnout 3: Takedown            1            1           NaN
# 20         10000  Burnout 3: Takedown            1            1           NaN
# 21         10000  Burnout 3: Takedown            1            1           NaN
# 22         10000  Burnout 3: Takedown            1            1           NaN
# 23         10000  Burnout 3: Takedown            1            1           NaN
# 24         10000  Burnout 3: Takedown            1            1           NaN
# 25         10000  Burnout 3: Takedown            1            1           NaN
# 26         10000  Burnout 3: Takedown            1            1           NaN
# 27         10000  Burnout 3: Takedown            1            1           NaN
# 28         10000  Burnout 3: Takedown            1            1           NaN
# 29         10000  Burnout 3: Takedown            1            1           NaN
# ...          ...                  ...          ...          ...           ...
# 1084659    26960          Pinball FX3            6            1  Jan  8, 2018
# 1084660    26960          Pinball FX3            6            1  Jan  2, 2018
# 1084661    26960          Pinball FX3            6            1  Jan  2, 2018
# 1084662    26960          Pinball FX3            6            1  Jan  2, 2018
# 1084663    26960          Pinball FX3            6            1  Jan  2, 2018
# 1084664    26960          Pinball FX3            6            1  Dec 21, 2017
# 1084665    26960          Pinball FX3            6            1  Jan 16, 2018
# 1084666    26960          Pinball FX3            6            1  Mar  9, 2018
# 1084667    26960          Pinball FX3            6            1  Dec 18, 2017
# 1084668    26960          Pinball FX3            6            1  Jan 15, 2018
# 1084669    26960          Pinball FX3            6            0  Dec 14, 2017
# 1084670    26960          Pinball FX3            6            0  Dec 18, 2017
# 1084671    26960          Pinball FX3            6            0  Dec 13, 2017
# 1084672    26960          Pinball FX3            6            0  Dec 25, 2017
# 1084673    26960          Pinball FX3            6            0  Jan 14, 2018
# 1084674    26960          Pinball FX3            6            0  Dec 23, 2017
# 1084675    26960          Pinball FX3            6            0  Jan  9, 2018
# 1084676    26960          Pinball FX3            6            0  Dec 13, 2017
# 1084677    26960          Pinball FX3            6            0  Mar  4, 2018
# 1084678    26960          Pinball FX3            6            0  Mar  8, 2018
# 1084679    26960          Pinball FX3            6            0  Dec 31, 2017
# 1084680    26960          Pinball FX3            6            0  Apr 26, 2018
# 1084681    26960          Pinball FX3            6            0  Jun 21, 2018
# 1084682    26960          Pinball FX3            6            0  Jun 20, 2018
# 1084683    26960          Pinball FX3            6            0  May 11, 2018
# 1084684    26960          Pinball FX3            6            0  Jan  3, 2019
# 1084685    26960          Pinball FX3            6            0  Nov 12, 2019
# 1084686    26960          Pinball FX3            6            0  Mar 24, 2019
# 1084687    26960          Pinball FX3            6            0  Dec  3, 2019
# 1084688    26960          Pinball FX3            6            0  Jun 25, 2020
#
#                                                review_text  score  \
# 0        To say that this game is "fast" is an understa...  100.0
# 1        Easy controls help you play chicken with oncom...  100.0
# 2        With its killer combo of great gameplay, aweso...  100.0
# 3        Every lap is terrifying...Polished to perfecti...  100.0
# 4        The combo of racing and combat is brilliantly ...  100.0
# 5        The visuals are cleaner, more vibrant, and ooz...  100.0
# 6        Hands down, the best arcade racer ever made. E...  100.0
# 7        Racing games have now changed forever, and ent...  100.0
# 8        Burnout 3 is special. It's not just another ra...  100.0
# 9        Astonishingly good...This is pure, balls-out s...  100.0
# 10       What with the totally aggressive but fun gamep...  100.0
# 11       Takedown is nearly flawless, with crisp graphi...  100.0
# 12       This is only marginally a racing game - it's a...  100.0
# 13       The new king of arcade racers. Think about eve...  100.0
# 14       You should buy it even if driving games rank s...  100.0
# 15       The speed of the game is incredible and as the...  100.0
# 16       I am no longer a fan but now a full-fledged ju...   99.0
# 17       It's the best racing game on the current gen c...   97.0
# 18       If you want more than this from an arcade race...   97.0
# 19       The videogame equivalent of Hurricane Ivan; ev...   97.0
# 20       The best console arcade racing game ever and p...   97.0
# 21       With amazingly addictive gameplay, fabulous gr...   96.0
# 22       A work of art, a piece crafted to such infinit...   96.0
# 23       Even EA haters will be anonymously purchasing ...   96.0
# 24       Without a shadow of a doubt the best in the se...   96.0
# 25       Aside from some minor annoyances (the announce...   96.0
# 26       My jaw also hit the floor when I had my first ...   95.0
# 27       Offers up insane speed, unequaled crash sequen...   95.0
# 28       Even if driving games aren't normally your thi...   95.0
# 29            EA has struck absolute gold with this title.   95.0
# ...                                                    ...    ...
# 1084659  It may have a sparse selection of tables on th...   80.0
# 1084660  Pinball FX3 on Nintendo Switch is probably the...   80.0
# 1084661  Pinball machines will always have a place in m...   80.0
# 1084662  This isn’t authentic pinball, but it isn’t try...   80.0
# 1084663  Pinball FX3 brings to the Nintendo Switch a we...   80.0
# 1084664  Even if it doesn’t necessarily revolutionise t...   80.0
# 1084665  Pinball FX 3 is a great update to a well renow...   75.0
# 1084666  Pinball FX3 brings to Nintendo Switch the feel...   70.0
# 1084667  Pinball FX3 leaves some things to be desired o...   70.0
# 1084668  I hope they patch these issues out because the...   65.0
# 1084669  I'm a long time pinball fan, both traditional ...    9.0
# 1084670  Pinball FX3 contains well-designed original pi...    8.0
# 1084671   This game has all the needs for all pinball l...    9.0
# 1084672   So finally, free games for Switch are finally...   10.0
# 1084673  Well, here we are. Pinball FX3 is probably the...    6.0
# 1084674  A solid game of pinball. You can set the game ...    8.0
# 1084675  I have played Zen's pinball games on multiple ...    5.0
# 1084676   This is ok i played one before and it was pre...    8.0
# 1084677   Surprisingly fun and addicting game.  I have ...    9.0
# 1084678   I like pinball and this is really fun if you ...    8.0
# 1084679  I have always loved pinball. I've found it cap...    4.0
# 1084680   Pinball FX3 is the best pinball game ever. An...   10.0
# 1084681   An accomplished pinball simulation with many ...    9.0
# 1084682  This is a great pinball game. It has a huge am...    9.0
# 1084683  some pinball games leave me cold bored but ori...    9.0
# 1084684   As with all pinball games, you will not like ...   10.0
# 1084685  PBFX3 is THE Pinball game to get if you like v...   10.0
# 1084686   Easily the best pinball game on Nintendo Swit...    9.0
# 1084687  Pinball FX3 is known as one of the best pinbal...    8.0
# 1084688  There is really nothing bad to say about this ...   10.0
#
#                                                        url  \
# 0        https://www.metacritic.com/game/xbox/burnout-3...
# 1        https://www.metacritic.com/game/xbox/burnout-3...
# 2        https://www.metacritic.com/game/xbox/burnout-3...
# 3        https://www.metacritic.com/game/xbox/burnout-3...
# 4        https://www.metacritic.com/game/xbox/burnout-3...
# 5        https://www.metacritic.com/game/xbox/burnout-3...
# 6        https://www.metacritic.com/game/xbox/burnout-3...
# 7        https://www.metacritic.com/game/xbox/burnout-3...
# 8        https://www.metacritic.com/game/xbox/burnout-3...
# 9        https://www.metacritic.com/game/xbox/burnout-3...
# 10       https://www.metacritic.com/game/xbox/burnout-3...
# 11       https://www.metacritic.com/game/xbox/burnout-3...
# 12       https://www.metacritic.com/game/xbox/burnout-3...
# 13       https://www.metacritic.com/game/xbox/burnout-3...
# 14       https://www.metacritic.com/game/xbox/burnout-3...
# 15       https://www.metacritic.com/game/xbox/burnout-3...
# 16       https://www.metacritic.com/game/xbox/burnout-3...
# 17       https://www.metacritic.com/game/xbox/burnout-3...
# 18       https://www.metacritic.com/game/xbox/burnout-3...
# 19       https://www.metacritic.com/game/xbox/burnout-3...
# 20       https://www.metacritic.com/game/xbox/burnout-3...
# 21       https://www.metacritic.com/game/xbox/burnout-3...
# 22       https://www.metacritic.com/game/xbox/burnout-3...
# 23       https://www.metacritic.com/game/xbox/burnout-3...
# 24       https://www.metacritic.com/game/xbox/burnout-3...
# 25       https://www.metacritic.com/game/xbox/burnout-3...
# 26       https://www.metacritic.com/game/xbox/burnout-3...
# 27       https://www.metacritic.com/game/xbox/burnout-3...
# 28       https://www.metacritic.com/game/xbox/burnout-3...
# 29       https://www.metacritic.com/game/xbox/burnout-3...
# ...                                                    ...
# 1084659  https://www.metacritic.com/game/switch/pinball...
# 1084660  https://www.metacritic.com/game/switch/pinball...
# 1084661  https://www.metacritic.com/game/switch/pinball...
# 1084662  https://www.metacritic.com/game/switch/pinball...
# 1084663  https://www.metacritic.com/game/switch/pinball...
# 1084664  https://www.metacritic.com/game/switch/pinball...
# 1084665  https://www.metacritic.com/game/switch/pinball...
# 1084666  https://www.metacritic.com/game/switch/pinball...
# 1084667  https://www.metacritic.com/game/switch/pinball...
# 1084668  https://www.metacritic.com/game/switch/pinball...
# 1084669  https://www.metacritic.com/game/switch/pinball...
# 1084670  https://www.metacritic.com/game/switch/pinball...
# 1084671  https://www.metacritic.com/game/switch/pinball...
# 1084672  https://www.metacritic.com/game/switch/pinball...
# 1084673  https://www.metacritic.com/game/switch/pinball...
# 1084674  https://www.metacritic.com/game/switch/pinball...
# 1084675  https://www.metacritic.com/game/switch/pinball...
# 1084676  https://www.metacritic.com/game/switch/pinball...
# 1084677  https://www.metacritic.com/game/switch/pinball...
# 1084678  https://www.metacritic.com/game/switch/pinball...
# 1084679  https://www.metacritic.com/game/switch/pinball...
# 1084680  https://www.metacritic.com/game/switch/pinball...
# 1084681  https://www.metacritic.com/game/switch/pinball...
# 1084682  https://www.metacritic.com/game/switch/pinball...
# 1084683  https://www.metacritic.com/game/switch/pinball...
# 1084684  https://www.metacritic.com/game/switch/pinball...
# 1084685  https://www.metacritic.com/game/switch/pinball...
# 1084686  https://www.metacritic.com/game/switch/pinball...
# 1084687  https://www.metacritic.com/game/switch/pinball...
# 1084688  https://www.metacritic.com/game/switch/pinball...
#
#                           username
# 0                          GamePro
# 1                     Maxim Online
# 2                            G4 TV
# 3        The Sydney Morning Herald
# 4             Entertainment Weekly
# 5                       Gaming Age
# 6             Xbox Nation Magazine
# 7                        Gamestyle
# 8                        games(TM)
# 9                      RewiredMind
# 10                        AceGamez
# 11              The New York Times
# 12                Operation Sports
# 13                         GameSpy
# 14                           Stuff
# 15              Australian GamePro
# 16                   Worth Playing
# 17                         GameBiz
# 18               Console Gameworld
# 19                           Kombo
# 20                        3DAvenue
# 21                     Da Gameboyz
# 22                  TotalGames.net
# 23                        TeamXbox
# 24             Inside Gamer Online
# 25                   Gaming Target
# 26                           VGPub
# 27                             IGN
# 28                        GameSpot
# 29                      Gamezilla!
# ...                            ...
# 1084659               Critical Hit
# 1084660             Multiplayer.it
# 1084661                      Vooks
# 1084662              Switch Player
# 1084663                  FNintendo
# 1084664              Nintendo Life
# 1084665           New Game Network
# 1084666                Nintenderos
# 1084667                     Cubed3
# 1084668              God is a Geek
# 1084669                     kenjab
# 1084670                Jack5switch
# 1084671               Voodooseeker
# 1084672              RUSArtemFokin
# 1084673                  LadyKalma
# 1084674                   Sanistus
# 1084675                 kennfusion
# 1084676                 Karbyman48
# 1084677             Jiminy_Cricket
# 1084678              NickSlyCooper
# 1084679                  BarcSsarc
# 1084680                 gustave154
# 1084681               Digibutter64
# 1084682                    jibbitt
# 1084683             KlingonGamerYT
# 1084684                      bl1rt
# 1084685                  hunter328
# 1084686                       JJTX
# 1084687                      nusco
# 1084688             DecoyDoctorpus
#
# [1084689 rows x 9 columns]

# %%
game_reviews.shape

# %% [markdown]
# #### Handling Missingness in the Reviews table

# %%
game_reviews.isnull().sum()
#critic reviews didn't have to have scores, but I decided to still pick up the text
#reviews do not have to have text! And these appear to be from lack of text
#many critic reviews do not have dates, though all user reviews do have dates
#why are usernames missing?

# %%
mask = game_reviews[['game_ID', 'username']].isnull().any(axis=1)
game_reviews[['game_ID', 'username']].loc[mask,:]

# %%
# These are actual usernames, with an account page, not nan values
game_reviews.loc[828177, 'username'] = 'N/A'
game_reviews.loc[2900, 'username'] = 'NULL'
game_reviews.loc[593409, 'username'] = 'NULL'
game_reviews.loc[595912, 'username'] = 'NULL'
game_reviews.loc[664027, 'username'] = 'NULL'
game_reviews.loc[842388, 'username'] = 'NULL'

# %% [markdown]
# #### Creating Users table and dropping extra columns on Reviews table:

# %%
users = pd.DataFrame(game_reviews[['username', 'critic_flag']].drop_duplicates())
users = users.reset_index(drop=True)
ids = pd.Series(range(1, 323199))
users = pd.concat((ids, users), axis=1)
users.columns = ['user_ID', 'username', 'critic_flag']
users.shape

# %%
# add new user ID to reviews table and droping the username and critic flag
game_reviews = pd.merge(users, game_reviews, how = "right", on = ['username', 'critic_flag'])
game_reviews = game_reviews.drop(['username', 'critic_flag'], 1)
game_reviews.head()

# %%
# re-arrange game_review columns for easier reading
game_reviews = game_reviews[['game_ID', 'user_ID', 'score', 'review_text', 'date']]
game_reviews.head()

# %%
game_ids[game_ids.game_ID == 10302]
